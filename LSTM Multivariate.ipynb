# %%
import numpy as np
import pandas as pd
from math import sqrt
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Model,Sequential 
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate
from keras.layers import LSTM, GRU
from keras import optimizers
from tqdm import tqdm
# Out:
# Using TensorFlow backend.

# %%
# import all stock prices
df_stock = pd.read_csv("NASDAQ_Composite.csv", index_col = 0)
df_stock.head()
# Out:
#               IXIC.Open    IXIC.High     IXIC.Low   IXIC.Close   IXIC.Volume  \
# TIMESTAMP
# 2010-01-04  2294.409912  2311.149902  2294.409912  2308.419922  1.931380e+09
# 2010-01-05  2307.270020  2313.729980  2295.620117  2308.709961  2.367860e+09
# 2010-01-06  2307.709961  2314.070068  2295.679932  2301.090088  2.253340e+09
# 2010-01-07  2298.090088  2301.300049  2285.219971  2300.050049  2.270050e+09
# 2010-01-08  2292.239990  2317.600098  2290.610107  2317.169922  2.145390e+09
#
#             IXIC.Adjusted
# TIMESTAMP
# 2010-01-04    2308.419922
# 2010-01-05    2308.709961
# 2010-01-06    2301.090088
# 2010-01-07    2300.050049
# 2010-01-08    2317.169922

# %%
# Economic Policy Uncertainty Index for United States 
df_uncertainty = pd.read_csv("USEPUINDXD.csv", index_col = 0)
df_uncertainty.head()
# Out:
#             USEPUINDXD
# DATE
# 2010-01-01      174.55
# 2010-01-02      119.52
# 2010-01-03      216.95
# 2010-01-04      150.35
# 2010-01-05      151.16

# %%
# ICE BofA US High Yield Index Option-Adjusted Spread
df_interest_rate = pd.read_csv("BAMLH0A0HYM2.csv", index_col = 0)
df_interest_rate.head()
# Out:
#            BAMLH0A0HYM2
# DATE
# 2010-01-04         6.34
# 2010-01-05         6.30
# 2010-01-06         6.17
# 2010-01-07         6.03
# 2010-01-08         6.02

# %%
# Replace the bad value with value nearby
df_interest_rate.loc[df_interest_rate.BAMLH0A0HYM2 == '.'] = np.nan
df_interest_rate[['BAMLH0A0HYM2']] = df_interest_rate[['BAMLH0A0HYM2']].apply(pd.to_numeric)
df_interest_rate['BAMLH0A0HYM2'].interpolate(method='linear', inplace=True)
df_interest_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2641 entries, 2010-01-04 to 2019-12-31
# Data columns (total 1 columns):
# BAMLH0A0HYM2    2641 non-null float64
# dtypes: float64(1)
# memory usage: 41.3+ KB

# %%
set_stock_dates = set(df_stock.index)
set_rate_dates = set(df_interest_rate.index)
set_uncertainty_dates = set(df_uncertainty.index)

# Take the difference between the sets and print
print(set_stock_dates - set_rate_dates)
print(set_stock_dates - set_uncertainty_dates)
# Out:
# set()
# set()

# %%
# Merge stocks and bonds DataFrames using join()
df = df_stock.join(df_interest_rate, how='left')
df = df.join(df_uncertainty, how='left')
df.head(10)
# Out:
#               IXIC.Open    IXIC.High     IXIC.Low   IXIC.Close   IXIC.Volume  \
# TIMESTAMP
# 2010-01-04  2294.409912  2311.149902  2294.409912  2308.419922  1.931380e+09
# 2010-01-05  2307.270020  2313.729980  2295.620117  2308.709961  2.367860e+09
# 2010-01-06  2307.709961  2314.070068  2295.679932  2301.090088  2.253340e+09
# 2010-01-07  2298.090088  2301.300049  2285.219971  2300.050049  2.270050e+09
# 2010-01-08  2292.239990  2317.600098  2290.610107  2317.169922  2.145390e+09
# 2010-01-11  2324.780029  2326.280029  2302.209961  2312.409912  2.077890e+09
# 2010-01-12  2297.280029  2298.850098  2272.699951  2282.310059  2.368320e+09
# 2010-01-13  2289.459961  2313.030029  2274.120117  2307.899902  2.318350e+09
# 2010-01-14  2303.310059  2322.560059  2303.290039  2316.739990  2.254170e+09
# 2010-01-15  2316.979980  2322.540039  2279.199951  2287.989990  2.637770e+09
#
#             IXIC.Adjusted  BAMLH0A0HYM2  USEPUINDXD
# TIMESTAMP
# 2010-01-04    2308.419922          6.34      150.35
# 2010-01-05    2308.709961          6.30      151.16
# 2010-01-06    2301.090088          6.17       95.95
# 2010-01-07    2300.050049          6.03       92.20
# 2010-01-08    2317.169922          6.02      141.92
# 2010-01-11    2312.409912          5.99      103.54
# 2010-01-12    2282.310059          6.07       99.13
# 2010-01-13    2307.899902          6.03       69.67
# 2010-01-14    2316.739990          6.04       87.42
# 2010-01-15    2287.989990          6.10      108.55

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2515 entries, 2010-01-04 to 2019-12-30
# Data columns (total 8 columns):
# IXIC.Open        2515 non-null float64
# IXIC.High        2515 non-null float64
# IXIC.Low         2515 non-null float64
# IXIC.Close       2515 non-null float64
# IXIC.Volume      2515 non-null float64
# IXIC.Adjusted    2515 non-null float64
# BAMLH0A0HYM2     2515 non-null float64
# USEPUINDXD       2515 non-null float64
# dtypes: float64(8)
# memory usage: 256.8+ KB

# %%
df.describe()
# Out:
#          IXIC.Open    IXIC.High     IXIC.Low   IXIC.Close   IXIC.Volume  \
# count  2515.000000  2515.000000  2515.000000  2515.000000  2.515000e+03
# mean   4741.647273  4766.420162  4714.043359  4742.476513  1.964577e+09
# std    1877.365514  1885.525754  1867.997740  1877.282870  3.977521e+08
# min    2099.659912  2110.659912  2061.139893  2091.790039  1.494100e+08
# 25%    2973.875000  2990.934936  2959.095093  2976.155029  1.736800e+09
# 50%    4623.770020  4651.899902  4570.229980  4620.370117  1.913230e+09
# 75%    6229.260009  6255.950195  6200.430175  6227.930175  2.141375e+09
# max    9049.469727  9052.000000  8987.320313  9022.389648  4.553600e+09
#
#        IXIC.Adjusted  BAMLH0A0HYM2   USEPUINDXD
# count    2515.000000   2515.000000  2515.000000
# mean     4742.476513      4.994185   103.942111
# std      1877.282870      1.228051    59.891208
# min      2091.790039      3.160000     3.320000
# 25%      2976.155029      3.935000    61.670000
# 50%      4620.370117      4.740000    89.610000
# 75%      6227.930175      5.915000   130.655000
# max      9022.389648      9.100000   490.890000

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1,2,1)
plt.plot(df['IXIC.Low'].values, color='red', label='low')
plt.plot(df['IXIC.High'].values, color='green', label='high')
plt.plot(df['IXIC.Adjusted'].values, color='orange', label='adjusted')
plt.plot(df['IXIC.Open'].values, color='blue', label='open')
plt.plot(df['IXIC.Close'].values, color='black', label='close')
plt.title('NASDAQ Composite stock price from Jan 2010 to Dec 2019')
plt.xlabel('time [days]')
plt.ylabel('price')
plt.legend(loc='best')


plt.subplot(1,2,2)
plt.plot(df['IXIC.Volume'].values, color='black', label='volume')
plt.title('NASDAQ Composite stock volume from Jan 2010 to Dec 2019')
plt.xlabel('time [days]')
plt.ylabel('volume')
plt.legend(loc='best')

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1,2,1)
plt.plot(df.BAMLH0A0HYM2.values, color='black', label='interest rate')
plt.title('Interest Rates from Jan 2010 to Dec 2019')
plt.xlabel('time [days]')
plt.ylabel('rates')
plt.legend(loc='best')

plt.subplot(1,2,2)
plt.plot(df.USEPUINDXD.values, color='black', label='volume')
plt.title('Economic Policy Uncertainty Index for United States  from Jan 2010 to Dec 2019')
plt.xlabel('time [days]')
plt.ylabel('volume')
plt.legend(loc='best')

# %%
# Moving average
close = df['IXIC.Close']
MA30 = close.rolling(window=30).mean()
MA120 = close.rolling(window=120).mean()
MA360 = close.rolling(window=360).mean()
plt.figure(figsize=(14, 7))
plt.plot(close.index, close, lw=3, alpha=0.8, label='Original observations')
plt.plot(close.index, MA30, lw=3, alpha=0.8, label='Rolling mean (window 30)')
plt.plot(close.index, MA120, lw=3, alpha=0.8, label='Rolling mean (window 120)')
plt.plot(close.index, MA360, lw=3, alpha=0.8, label='Rolling mean (window 360)')
plt.title('NASDAQ Composite stock Close Price 2010-01-01 to 2019-12-31')
plt.legend(loc='best')
plt.show()

# %%
# Exponential Moving Average
exp_weighted_mean = close.ewm(span=360).mean()
sma_d10 = close.rolling(window=360).mean()
ax = close.plot(lw=3, figsize=(14, 7), label='Original observations')
exp_weighted_mean.plot(ax=ax, lw=3, label='EMA (window 365)')
sma_d10.plot(ax=ax, lw=3, label='SMA (window 365)')
plt.title('NASDAQ Composite stock Close Price 2010-01-01 to 2019-12-31')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# From the above chart, you can see EMA in orange line catches the downwards movement in Dec 2015 and Dec 2018 faster than SMA in green line. And also at early 2016, EMA started to catch upwards movement, while SMA still showing downwards trend.

# %%
# Generate more features for prediction from Exponential Moving Average
df['EMA120'] = df['IXIC.Close'].ewm(span=120, adjust=False).mean()
df['EMA360'] = df['IXIC.Close'].ewm(span=360, adjust=False).mean()

df['dist_EMA120'] = (df['IXIC.Close'] - df['EMA120'])/df['EMA120']*100
df['dist_EMA360'] = (df['IXIC.Close'] - df['EMA360'])/df['EMA360']*100

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(df_stock.index[:120], df['dist_EMA120'][:120], label='dist_EMA120')
ax.plot(df_stock.index[:120], df['dist_EMA360'][:120], label='dist_EMA360')
ax.set_xlabel('day')
ax.set_ylabel('distance from moving mean')
ax.legend(loc='best')

# %% [markdown]
# # LSTM Data Preparation
#
# The first step is to prepare the dataset for the LSTM.
#
# This involves framing the dataset as a supervised learning problem and normalizing the input variables.
#
# We will frame the supervised learning problem as predicting the close stock price at the current day given all the features at the prior time step.
#
# This formulation is straightforward and just for this demonstration. Some alternate formulations you could explore include:
#
# Predict the pollution for the next hour based on the weather conditions and pollution over the last 24 hours.
# Predict the pollution for the next hour as above and given the “expected” weather conditions for the next hour.

# %%
# split the dataset into two parts: a training set (2010-2018) and a test set (2019).
df_train = df['2010-01-01':'2018-12-31']
df_test = df['2019-01-01':'2019-12-31']
print('Length of data from Jan 2010 to Dec 2018 is', df_train.shape[0])
print('Length of data from Jan 2019 to Dec 2019 is', df_test.shape[0])
# Out:
# Length of data from Jan 2010 to Dec 2018 is 2264
# Length of data from Jan 2019 to Dec 2019 is 251

# %%
features = ['IXIC.Open', 'IXIC.Close', 'IXIC.High', 'IXIC.Low', 'IXIC.Adjusted', 'IXIC.Volume',
            'BAMLH0A0HYM2', 'USEPUINDXD', 'dist_EMA120', 'dist_EMA360']

# get data value
values = df[features].values
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
values = scaler.fit_transform(values)

# %%
lookback = 250
lookahead = 1
X = np.array([values[i:i+lookback].copy() for i in range(len(values)-lookback-lookahead)])
y = np.array([values[i+lookback+lookahead-1, 1] for i in range(len(values)-lookback-lookahead)]) # close price
print('X.shape = ', X.shape)
print('y.shape = ', y.shape)
# Out:
# X.shape =  (2264, 250, 10)
# y.shape =  (2264,)

# %%
X_train, X_test = X[0:-251,:,:], X[-251:,:,:]
y_train, y_test = y[:-251], y[-251:]

print('X_train.shape = ', X_train.shape)
print('X_test.shape = ', X_test.shape)
print('y_train.shape = ', y_train.shape)
print('y_test.shape = ', y_test.shape)
# Out:
# X_train.shape =  (2013, 250, 10)
# X_test.shape =  (251, 250, 10)
# y_train.shape =  (2013,)
# y_test.shape =  (251,)

# %%
# design network
model = Sequential()
model.add(LSTM(256, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.4))
model.add(Dense(64 , activation = 'relu'))
model.add(Dense(1))
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 256)               273408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 289,921
# Trainable params: 289,921
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(loss='mean_squared_error', optimizer='adam', metrics = ['mean_squared_error'])
history = model.fit(X_train, y_train, epochs=100, batch_size = 128, 
                    validation_data=(X_test, y_test), shuffle=False)
# Out:
# Train on 2013 samples, validate on 251 samples
# Epoch 1/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 2/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 0.0374 - mean_squared_error: 0.0374 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
# Epoch 3/100
# 2013/2013 [==============================] - 13s 7ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 4/100
# 2013/2013 [==============================] - 13s 7ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 5/100
# 2013/2013 [==============================] - 13s 7ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 8.8657e-04 - val_mean_squared_error: 8.8657e-04
# Epoch 6/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
# Epoch 7/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 8/100
# 2013/2013 [==============================] - 13s 7ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 9/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 5.1626e-04 - val_mean_squared_error: 5.1626e-04
# Epoch 10/100
# 2013/2013 [==============================] - 13s 6ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 11/100
# 2013/2013 [==============================] - 12s 6ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 4.9949e-04 - val_mean_squared_error: 4.9949e-04
# Epoch 12/100
# 2013/2013 [==============================] - 12s 6ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 7.4067e-04 - val_mean_squared_error: 7.4067e-04
# Epoch 13/100
# 2013/2013 [==============================] - 12s 6ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 14/100
# 2013/2013 [==============================] - 12s 6ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 15/100
# 2013/2013 [==============================] - 12s 6ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 16/100
# 2013/2013 [==============================] - 12s 6ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 17/100
# 2013/2013 [==============================] - 12s 6ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 8.0778e-04 - val_mean_squared_error: 8.0778e-04
# Epoch 18/100
# 2013/2013 [==============================] - 12s 6ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 3.5443e-04 - val_mean_squared_error: 3.5443e-04
# Epoch 19/100
# 2013/2013 [==============================] - 12s 6ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 8.2318e-04 - val_mean_squared_error: 8.2318e-04
# Epoch 20/100
# 2013/2013 [==============================] - 13s 6ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 21/100
# 2013/2013 [==============================] - 13s 6ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 8.6479e-04 - val_mean_squared_error: 8.6479e-04
# Epoch 22/100
# 2013/2013 [==============================] - 13s 6ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 2.5986e-04 - val_mean_squared_error: 2.5986e-04
# Epoch 23/100
# 2013/2013 [==============================] - 13s 6ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 6.6908e-04 - val_mean_squared_error: 6.6908e-04
# Epoch 24/100
# 2013/2013 [==============================] - 13s 6ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 25/100
# 2013/2013 [==============================] - 13s 6ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 5.3117e-04 - val_mean_squared_error: 5.3117e-04
# Epoch 26/100
# 2013/2013 [==============================] - 13s 6ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 2.0814e-04 - val_mean_squared_error: 2.0814e-04
# Epoch 27/100
# 2013/2013 [==============================] - 13s 6ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 8.2952e-04 - val_mean_squared_error: 8.2952e-04
# Epoch 28/100
# 2013/2013 [==============================] - 13s 6ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 29/100
# 2013/2013 [==============================] - 13s 6ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 1.9706e-04 - val_mean_squared_error: 1.9706e-04
# Epoch 30/100
# 2013/2013 [==============================] - 13s 6ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 2.2346e-04 - val_mean_squared_error: 2.2346e-04
# Epoch 31/100
# 2013/2013 [==============================] - 13s 6ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 9.8164e-04 - val_mean_squared_error: 9.8164e-04
# Epoch 32/100
# 2013/2013 [==============================] - 13s 7ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 33/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 2.8500e-04 - val_mean_squared_error: 2.8500e-04
# Epoch 34/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 1.9699e-04 - val_mean_squared_error: 1.9699e-04
# Epoch 35/100
# 2013/2013 [==============================] - 16s 8ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 36/100
# 2013/2013 [==============================] - 15s 7ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 37/100
# 2013/2013 [==============================] - 18s 9ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 8.0974e-04 - val_mean_squared_error: 8.0974e-04
# Epoch 38/100
# 2013/2013 [==============================] - 13s 7ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 4.2021e-04 - val_mean_squared_error: 4.2021e-04
# Epoch 39/100
# 2013/2013 [==============================] - 21s 10ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 40/100
# 2013/2013 [==============================] - 15s 7ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 41/100
# 2013/2013 [==============================] - 19s 9ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 42/100
# 2013/2013 [==============================] - 18s 9ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 43/100
# 2013/2013 [==============================] - 19s 9ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 44/100
# 2013/2013 [==============================] - 19s 10ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 45/100
# 2013/2013 [==============================] - 23s 11ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 2.3278e-04 - val_mean_squared_error: 2.3278e-04
# Epoch 46/100
# 2013/2013 [==============================] - 22s 11ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 47/100
# 2013/2013 [==============================] - 23s 11ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.7422e-04 - val_mean_squared_error: 7.7422e-04
# Epoch 48/100
# 2013/2013 [==============================] - 23s 11ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 2.7739e-04 - val_mean_squared_error: 2.7739e-04
# Epoch 49/100
# 2013/2013 [==============================] - 23s 11ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 50/100
# 2013/2013 [==============================] - 23s 11ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 51/100
# 2013/2013 [==============================] - 23s 11ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 2.8349e-04 - val_mean_squared_error: 2.8349e-04
# Epoch 52/100
# 2013/2013 [==============================] - 23s 11ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.8020e-04 - val_mean_squared_error: 6.8020e-04
# Epoch 53/100
# 2013/2013 [==============================] - 22s 11ms/step - loss: 8.1426e-04 - mean_squared_error: 8.1426e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 54/100
# 2013/2013 [==============================] - 22s 11ms/step - loss: 9.3900e-04 - mean_squared_error: 9.3900e-04 - val_loss: 3.0187e-04 - val_mean_squared_error: 3.0187e-04
# Epoch 55/100
# 2013/2013 [==============================] - 23s 11ms/step - loss: 6.9586e-04 - mean_squared_error: 6.9586e-04 - val_loss: 2.2768e-04 - val_mean_squared_error: 2.2768e-04
# Epoch 56/100
# 2013/2013 [==============================] - 23s 11ms/step - loss: 9.4635e-04 - mean_squared_error: 9.4635e-04 - val_loss: 5.7516e-04 - val_mean_squared_error: 5.7516e-04
# Epoch 57/100
# 2013/2013 [==============================] - 24s 12ms/step - loss: 6.5163e-04 - mean_squared_error: 6.5163e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 58/100
# 2013/2013 [==============================] - 22s 11ms/step - loss: 8.9884e-04 - mean_squared_error: 8.9884e-04 - val_loss: 2.2996e-04 - val_mean_squared_error: 2.2996e-04
# Epoch 59/100
# 2013/2013 [==============================] - 22s 11ms/step - loss: 7.0800e-04 - mean_squared_error: 7.0800e-04 - val_loss: 2.1533e-04 - val_mean_squared_error: 2.1533e-04
# Epoch 60/100
# 2013/2013 [==============================] - 21s 10ms/step - loss: 9.8468e-04 - mean_squared_error: 9.8468e-04 - val_loss: 9.1258e-04 - val_mean_squared_error: 9.1258e-04
# Epoch 61/100
# 2013/2013 [==============================] - 13s 7ms/step - loss: 7.9261e-04 - mean_squared_error: 7.9261e-04 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 62/100
# 2013/2013 [==============================] - 22s 11ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 2.8595e-04 - val_mean_squared_error: 2.8595e-04
# Epoch 63/100
# 2013/2013 [==============================] - 15s 7ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 2.6831e-04 - val_mean_squared_error: 2.6831e-04
# Epoch 64/100
# 2013/2013 [==============================] - 13s 7ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 65/100
# 2013/2013 [==============================] - 13s 7ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 66/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 6.0865e-04 - val_mean_squared_error: 6.0865e-04
# Epoch 67/100
# 2013/2013 [==============================] - 15s 7ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 9.0764e-04 - val_mean_squared_error: 9.0764e-04
# Epoch 68/100
# 2013/2013 [==============================] - 16s 8ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 69/100
# 2013/2013 [==============================] - 15s 7ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 2.4084e-04 - val_mean_squared_error: 2.4084e-04
# Epoch 70/100
# 2013/2013 [==============================] - 15s 7ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 2.0350e-04 - val_mean_squared_error: 2.0350e-04
# Epoch 71/100
# 2013/2013 [==============================] - 17s 8ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 72/100
# 2013/2013 [==============================] - 15s 8ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 73/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 8.1106e-04 - val_mean_squared_error: 8.1106e-04
# Epoch 74/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 2.5442e-04 - val_mean_squared_error: 2.5442e-04
# Epoch 75/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 76/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 1.9373e-04 - val_mean_squared_error: 1.9373e-04
# Epoch 77/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 2.2967e-04 - val_mean_squared_error: 2.2967e-04
# Epoch 78/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 79/100
# 2013/2013 [==============================] - 15s 7ms/step - loss: 9.6387e-04 - mean_squared_error: 9.6387e-04 - val_loss: 8.5616e-04 - val_mean_squared_error: 8.5616e-04
# Epoch 80/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 3.3513e-04 - val_mean_squared_error: 3.3513e-04
# Epoch 81/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 9.6473e-04 - val_mean_squared_error: 9.6473e-04
# Epoch 82/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 8.1993e-04 - mean_squared_error: 8.1993e-04 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 83/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 2.2274e-04 - val_mean_squared_error: 2.2274e-04
# Epoch 84/100
# 2013/2013 [==============================] - 15s 7ms/step - loss: 7.4846e-04 - mean_squared_error: 7.4846e-04 - val_loss: 2.5617e-04 - val_mean_squared_error: 2.5618e-04
# Epoch 85/100
# 2013/2013 [==============================] - 15s 8ms/step - loss: 8.7487e-04 - mean_squared_error: 8.7487e-04 - val_loss: 8.0040e-04 - val_mean_squared_error: 8.0040e-04
# Epoch 86/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 6.3444e-04 - mean_squared_error: 6.3444e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 87/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 8.8715e-04 - mean_squared_error: 8.8715e-04 - val_loss: 2.2746e-04 - val_mean_squared_error: 2.2746e-04
# Epoch 88/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 9.8519e-04 - mean_squared_error: 9.8519e-04 - val_loss: 3.5049e-04 - val_mean_squared_error: 3.5049e-04
# Epoch 89/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 7.3591e-04 - mean_squared_error: 7.3591e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 90/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 2.6902e-04 - val_mean_squared_error: 2.6902e-04
# Epoch 91/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 8.0057e-04 - mean_squared_error: 8.0057e-04 - val_loss: 2.8549e-04 - val_mean_squared_error: 2.8549e-04
# Epoch 92/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 9.2985e-04 - val_mean_squared_error: 9.2985e-04
# Epoch 93/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 8.7684e-04 - mean_squared_error: 8.7684e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 94/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 8.3673e-04 - val_mean_squared_error: 8.3673e-04
# Epoch 95/100
# 2013/2013 [==============================] - 15s 7ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 6.2903e-04 - val_mean_squared_error: 6.2903e-04
# Epoch 96/100
# 2013/2013 [==============================] - 15s 7ms/step - loss: 8.1433e-04 - mean_squared_error: 8.1433e-04 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 97/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 2.9305e-04 - val_mean_squared_error: 2.9305e-04
# Epoch 98/100
# 2013/2013 [==============================] - 15s 7ms/step - loss: 7.9297e-04 - mean_squared_error: 7.9297e-04 - val_loss: 2.5396e-04 - val_mean_squared_error: 2.5396e-04
# Epoch 99/100
# 2013/2013 [==============================] - 15s 8ms/step - loss: 8.9446e-04 - mean_squared_error: 8.9446e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 100/100
# 2013/2013 [==============================] - 14s 7ms/step - loss: 7.4123e-04 - mean_squared_error: 7.4123e-04 - val_loss: 4.1625e-04 - val_mean_squared_error: 4.1625e-04

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
trainScore = model.evaluate(X_train, y_train, verbose=0)
print('Train Score: %.5f MSE (%.2f RMSE)' % (trainScore[0], sqrt(trainScore[0])))

testScore = model.evaluate(X_test, y_test, verbose=0)
print('Test Score: %.5f MSE (%.2f RMSE)' % (testScore[0], sqrt(testScore[0])))
# Out:
# Train Score: 0.00018 MSE (0.01 RMSE)
# Test Score: 0.00042 MSE (0.02 RMSE)

# %%
from sklearn.metrics import r2_score
y_pred = model.predict(X_test)
print(r2_score(y_test, y_pred))
# Out:
# 0.908830747490149

# %%
plt.figure(figsize=(10,5))
plt.plot(y_test, linewidth=3)
plt.plot(y_pred, linewidth=3)
plt.legend(('Test','Forcasted'))
plt.show()

# %%
def denormalize(df, normalized_value): 
    df = df['IXIC.Close'].values.reshape(-1,1)
    normalized_value = normalized_value.reshape(-1,1)
    
    scaler = MinMaxScaler()
    a = scaler.fit_transform(df)
    return scaler.inverse_transform(normalized_value)

new_pred = denormalize(df[features], y_pred)
new_y_test = denormalize(df, y_test)

# %%
plt.figure(figsize=(10,5))
plt.plot(new_y_test, linewidth=3)
plt.plot(new_pred, linewidth=3)
plt.title('Compare the model performance on denormalized NASDAQ 2019 data')
plt.legend(('Test','Forcasted'))
plt.show()
